# %%
import mwclient  # Library for interacting with MediaWiki-based wikis, such as Wikipedia
import time  # Library for time-related functions
from transformers import pipeline  # Library for accessing pre-trained models for various NLP tasks
from statistics import mean  # Library for statistical calculations, such as mean
import pandas as pd  # Library for data manipulation and analysis
from datetime import datetime  # Library for handling dates and times

# %% [markdown]
# # Finding sentiments of page edits

# %%
# Connect to the English Wikipedia site
site = mwclient.Site('en.wikipedia.org')

# Access the Wikipedia page for 'Bitcoin'
page = site.pages['Bitcoin']

# %%
# Retrieve and list all revisions of the 'Bitcoin' Wikipedia page
revs = list(page.revisions())

# %%
# Access the most recent revision of the 'Bitcoin' Wikipedia page
revs[0]
# Out:
# OrderedDict([('revid', 1240407957),
#              ('parentid', 1239083268),
#              ('user', 'Citation bot'),
#              ('timestamp',
#               time.struct_time(tm_year=2024, tm_mon=8, tm_mday=15, tm_hour=6, tm_min=35, tm_sec=19, tm_wday=3, tm_yday=228, tm_isdst=-1)),
#              ('comment',
#               'Altered title. Add: bibcode, authors 1-1. Removed parameters. Some additions/deletions were parameter name changes. | [[:en:WP:UCB|Use this bot]]. [[:en:WP:DBUG|Report bugs]]. | Suggested by Abductive | [[Category:Bitcoin]] | #UCB_Category 40/42')])

# %%
# Sort the list of revisions by their timestamp in ascending order
revs = sorted(revs, key=lambda rev: rev['timestamp'])

# %%
# Access the earliest revision of the 'Bitcoin' Wikipedia page after sorting by timestamp
revs[0]
# Out:
# OrderedDict([('revid', 275832581),
#              ('parentid', 0),
#              ('user', 'Pratyeka'),
#              ('timestamp',
#               time.struct_time(tm_year=2009, tm_mon=3, tm_mday=8, tm_hour=16, tm_min=41, tm_sec=7, tm_wday=6, tm_yday=67, tm_isdst=-1)),
#              ('comment', 'creation (stub)')])

# %%
# Initialize a sentiment analysis pipeline from Hugging Face's transformers library
sentiment_pipeline = pipeline('sentiment-analysis')

def find_sentiment(text):
    """
    Analyzes the sentiment of a given text.

    Parameters:
    - text (str): The text to analyze for sentiment.

    Returns:
    - float: The sentiment score of the text. Negative score indicates negative sentiment.
    """
    # Analyze sentiment of the first 250 characters of the text
    sent = sentiment_pipeline([text[:250]])[0]
    score = sent['score']  # Get the sentiment score
    if sent['label'] == 'NEGATIVE':  # If sentiment is negative, invert the score
        score *= -1
    return score
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# c:\Users\uzair\.conda\envs\datascience\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# c:\Users\uzair\.conda\envs\datascience\lib\random.py:370: DeprecationWarning: non-integer arguments to randrange() have been deprecated since Python 3.10 and will be removed in a subsequent version
#   return self.randrange(a, b+1)
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
# Analyze the sentiment of the phrase 'i love you'
find_sentiment('i love you')
# Out:
# 0.9998656511306763

# %%
# Analyze the sentiment of the phrase 'i hate you'
find_sentiment('i hate you')
# Out:
# -0.9991129040718079

# %%
# Initialize an empty dictionary to store edits or modifications
edits = {}

# %%
# Process each revision to categorize edits by date and analyze sentiment of edit comments
for rev in revs:
    # Format the revision timestamp as a date string
    date = time.strftime('%Y-%m-%d', rev["timestamp"])
    
    # Initialize the dictionary entry for the date if it doesn't exist
    if date not in edits:
        edits[date] = dict(sentiments=list(), edit_count=0)
    
    # Increment the edit count for the date
    edits[date]['edit_count'] += 1
    
    # Retrieve and analyze the comment from the revision
    comment = rev.get("comment", "")
    edits[date]["sentiments"].append(find_sentiment(comment))

# %%
# Calculate average sentiment and proportion of negative sentiments for each date
for key in edits:
    if len(edits[key]['sentiments']) > 0:
        # Compute the average sentiment score for the date
        edits[key]['sentiment'] = mean(edits[key]['sentiments'])
        # Calculate the proportion of negative sentiments
        edits[key]['neg_sentiment'] = len([s for s in edits[key]['sentiments'] if s < 0]) / len(edits[key]['sentiments'])
    else:
        # If no sentiments were recorded, set sentiment values to 0
        edits[key]['sentiment'] = 0
        edits[key]['neg_sentiment'] = 0
    
    # Remove the raw sentiment list, as it's no longer needed
    del edits[key]['sentiments']

# %%
# Display the final dictionary containing the processed edit information
edits
# Out:
# {'2009-03-08': {'edit_count': 4,
#   'sentiment': -0.550525039434433,
#   'neg_sentiment': 0.75},
#  '2009-08-05': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2009-08-06': {'edit_count': 2,
#   'sentiment': 0.995745837688446,
#   'neg_sentiment': 0.0},
#  '2009-08-14': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2009-10-13': {'edit_count': 2,
#   'sentiment': -0.22749891877174377,
#   'neg_sentiment': 0.5},
#  '2009-11-18': {'edit_count': 1,
#   'sentiment': 0.8839514255523682,
#   'neg_sentiment': 0.0},
#  '2009-12-08': {'edit_count': 1,
#   'sentiment': -0.9869275689125061,
#   'neg_sentiment': 1.0},
#  '2009-12-17': {'edit_count': 1,
#   'sentiment': -0.9975171089172363,
#   'neg_sentiment': 1.0},
#  '2010-02-23': {'edit_count': 1,
#   'sentiment': -0.9994946718215942,
#   'neg_sentiment': 1.0},
#  '2010-03-18': {'edit_count': 1,
#   'sentiment': 0.8758782148361206,
#   'neg_sentiment': 0.0},
#  '2010-04-13': {'edit_count': 4,
#   'sentiment': 0.8443562537431717,
#   'neg_sentiment': 0.0},
#  '2010-04-15': {'edit_count': 8,
#   'sentiment': 0.5781016498804092,
#   'neg_sentiment': 0.125},
#  '2010-04-28': {'edit_count': 2,
#   'sentiment': -0.1209430992603302,
#   'neg_sentiment': 0.5},
#  '2010-05-13': {'edit_count': 1,
#   'sentiment': -0.9664835929870605,
#   'neg_sentiment': 1.0},
#  '2010-06-17': {'edit_count': 2,
#   'sentiment': 0.995745837688446,
#   'neg_sentiment': 0.0},
#  '2010-06-18': {'edit_count': 9,
#   'sentiment': 0.35891928937700057,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-06-19': {'edit_count': 1,
#   'sentiment': 0.9875591397285461,
#   'neg_sentiment': 0.0},
#  '2010-06-20': {'edit_count': 3,
#   'sentiment': 0.9683798948923746,
#   'neg_sentiment': 0.0},
#  '2010-06-21': {'edit_count': 7,
#   'sentiment': 0.6157870462962559,
#   'neg_sentiment': 0.14285714285714285},
#  '2010-06-23': {'edit_count': 4,
#   'sentiment': 0.854963481426239,
#   'neg_sentiment': 0.0},
#  '2010-06-28': {'edit_count': 4,
#   'sentiment': 0.2831648886203766,
#   'neg_sentiment': 0.25},
#  '2010-06-29': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2010-07-05': {'edit_count': 1,
#   'sentiment': 0.9360675811767578,
#   'neg_sentiment': 0.0},
#  '2010-07-07': {'edit_count': 2,
#   'sentiment': -0.15275588631629944,
#   'neg_sentiment': 0.5},
#  '2010-07-08': {'edit_count': 2,
#   'sentiment': 0.01902487874031067,
#   'neg_sentiment': 0.5},
#  '2010-07-09': {'edit_count': 1,
#   'sentiment': -0.9049835205078125,
#   'neg_sentiment': 1.0},
#  '2010-07-11': {'edit_count': 13,
#   'sentiment': 0.32116303077110875,
#   'neg_sentiment': 0.3076923076923077},
#  '2010-07-12': {'edit_count': 9,
#   'sentiment': -0.28780010011461044,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-07-13': {'edit_count': 4,
#   'sentiment': 0.8065185397863388,
#   'neg_sentiment': 0.0},
#  '2010-07-14': {'edit_count': 4,
#   'sentiment': -0.06081317365169525,
#   'neg_sentiment': 0.5},
#  '2010-07-15': {'edit_count': 4,
#   'sentiment': -0.8949345350265503,
#   'neg_sentiment': 1.0},
#  '2010-07-16': {'edit_count': 6,
#   'sentiment': 0.9474908212820689,
#   'neg_sentiment': 0.0},
#  '2010-07-18': {'edit_count': 2,
#   'sentiment': -0.19054335355758667,
#   'neg_sentiment': 0.5},
#  '2010-07-19': {'edit_count': 4,
#   'sentiment': 0.8687814623117447,
#   'neg_sentiment': 0.0},
#  '2010-07-21': {'edit_count': 17,
#   'sentiment': -0.5357089393279132,
#   'neg_sentiment': 0.7647058823529411},
#  '2010-07-22': {'edit_count': 1,
#   'sentiment': -0.9933270215988159,
#   'neg_sentiment': 1.0},
#  '2010-07-25': {'edit_count': 4,
#   'sentiment': -0.0620153546333313,
#   'neg_sentiment': 0.5},
#  '2010-07-29': {'edit_count': 3,
#   'sentiment': 0.33770177761713666,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-08-03': {'edit_count': 3,
#   'sentiment': -0.9907000064849854,
#   'neg_sentiment': 1.0},
#  '2010-08-12': {'edit_count': 9,
#   'sentiment': 0.2590411172972785,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-08-14': {'edit_count': 1,
#   'sentiment': -0.9994552731513977,
#   'neg_sentiment': 1.0},
#  '2010-08-18': {'edit_count': 1,
#   'sentiment': -0.999642014503479,
#   'neg_sentiment': 1.0},
#  '2010-08-21': {'edit_count': 1,
#   'sentiment': -0.9951968789100647,
#   'neg_sentiment': 1.0},
#  '2010-09-20': {'edit_count': 1,
#   'sentiment': -0.9341222047805786,
#   'neg_sentiment': 1.0},
#  '2010-09-26': {'edit_count': 2,
#   'sentiment': -0.9957654178142548,
#   'neg_sentiment': 1.0},
#  '2010-09-27': {'edit_count': 2,
#   'sentiment': -0.9451582431793213,
#   'neg_sentiment': 1.0},
#  '2010-09-29': {'edit_count': 1,
#   'sentiment': -0.9989383816719055,
#   'neg_sentiment': 1.0},
#  '2010-10-02': {'edit_count': 1,
#   'sentiment': -0.9153549075126648,
#   'neg_sentiment': 1.0},
#  '2010-10-05': {'edit_count': 1,
#   'sentiment': -0.9941518902778625,
#   'neg_sentiment': 1.0},
#  '2010-10-19': {'edit_count': 1,
#   'sentiment': 0.6267805695533752,
#   'neg_sentiment': 0.0},
#  '2010-11-10': {'edit_count': 1,
#   'sentiment': 0.9957577586174011,
#   'neg_sentiment': 0.0},
#  '2010-11-11': {'edit_count': 1,
#   'sentiment': -0.9928996562957764,
#   'neg_sentiment': 1.0},
#  '2010-11-25': {'edit_count': 1,
#   'sentiment': -0.962530791759491,
#   'neg_sentiment': 1.0},
#  '2010-11-26': {'edit_count': 3,
#   'sentiment': -0.296960711479187,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-11-28': {'edit_count': 1,
#   'sentiment': -0.9982038736343384,
#   'neg_sentiment': 1.0},
#  '2010-12-01': {'edit_count': 1,
#   'sentiment': 0.9957577586174011,
#   'neg_sentiment': 0.0},
#  '2010-12-05': {'edit_count': 3,
#   'sentiment': 0.2574625611305237,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-12-10': {'edit_count': 15,
#   'sentiment': 0.36348610719045005,
#   'neg_sentiment': 0.26666666666666666},
#  '2010-12-11': {'edit_count': 50,
#   'sentiment': 0.2286207163333893,
#   'neg_sentiment': 0.32},
#  '2010-12-12': {'edit_count': 17,
#   'sentiment': -0.3360808912445517,
#   'neg_sentiment': 0.6470588235294118},
#  '2010-12-13': {'edit_count': 12,
#   'sentiment': -0.8279572079579035,
#   'neg_sentiment': 0.9166666666666666},
#  '2010-12-14': {'edit_count': 49,
#   'sentiment': -0.3559753554207938,
#   'neg_sentiment': 0.6938775510204082},
#  '2010-12-15': {'edit_count': 19,
#   'sentiment': -0.1553040209569429,
#   'neg_sentiment': 0.5789473684210527},
#  '2010-12-16': {'edit_count': 11,
#   'sentiment': -0.6393263285810297,
#   'neg_sentiment': 0.8181818181818182},
#  '2010-12-17': {'edit_count': 4,
#   'sentiment': -0.8237830102443695,
#   'neg_sentiment': 1.0},
#  '2010-12-18': {'edit_count': 2,
#   'sentiment': -0.9995501041412354,
#   'neg_sentiment': 1.0},
#  '2010-12-19': {'edit_count': 5,
#   'sentiment': -0.8360067486763001,
#   'neg_sentiment': 1.0},
#  '2010-12-20': {'edit_count': 22,
#   'sentiment': -0.28941320289265027,
#   'neg_sentiment': 0.6363636363636364},
#  '2010-12-21': {'edit_count': 27,
#   'sentiment': -0.3799964366135774,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-12-22': {'edit_count': 25,
#   'sentiment': -0.4561319804191589,
#   'neg_sentiment': 0.72},
#  '2010-12-23': {'edit_count': 2,
#   'sentiment': 0.9408828020095825,
#   'neg_sentiment': 0.0},
#  '2010-12-24': {'edit_count': 1,
#   'sentiment': -0.9991777539253235,
#   'neg_sentiment': 1.0},
#  '2011-01-01': {'edit_count': 1,
#   'sentiment': 0.9105640649795532,
#   'neg_sentiment': 0.0},
#  '2011-01-06': {'edit_count': 1,
#   'sentiment': -0.9996631145477295,
#   'neg_sentiment': 1.0},
#  '2011-01-07': {'edit_count': 3,
#   'sentiment': 0.1684613823890686,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-01-10': {'edit_count': 4,
#   'sentiment': -0.06684884428977966,
#   'neg_sentiment': 0.5},
#  '2011-01-11': {'edit_count': 2,
#   'sentiment': -0.9993845224380493,
#   'neg_sentiment': 1.0},
#  '2011-01-14': {'edit_count': 2,
#   'sentiment': -0.17865359783172607,
#   'neg_sentiment': 0.5},
#  '2011-01-16': {'edit_count': 10,
#   'sentiment': -0.3019537150859833,
#   'neg_sentiment': 0.6},
#  '2011-01-17': {'edit_count': 8,
#   'sentiment': -0.0648876428604126,
#   'neg_sentiment': 0.5},
#  '2011-01-20': {'edit_count': 1,
#   'sentiment': -0.6644972562789917,
#   'neg_sentiment': 1.0},
#  '2011-01-21': {'edit_count': 6,
#   'sentiment': -0.09091722965240479,
#   'neg_sentiment': 0.5},
#  '2011-01-22': {'edit_count': 1,
#   'sentiment': -0.945627748966217,
#   'neg_sentiment': 1.0},
#  '2011-01-24': {'edit_count': 4,
#   'sentiment': -0.4781821221113205,
#   'neg_sentiment': 0.75},
#  '2011-01-25': {'edit_count': 1,
#   'sentiment': -0.5590007901191711,
#   'neg_sentiment': 1.0},
#  '2011-01-26': {'edit_count': 1,
#   'sentiment': -0.9716881513595581,
#   'neg_sentiment': 1.0},
#  '2011-01-29': {'edit_count': 2,
#   'sentiment': -0.7818924486637115,
#   'neg_sentiment': 1.0},
#  '2011-01-31': {'edit_count': 1,
#   'sentiment': -0.9942212104797363,
#   'neg_sentiment': 1.0},
#  '2011-02-01': {'edit_count': 3,
#   'sentiment': -0.9960161050160726,
#   'neg_sentiment': 1.0},
#  '2011-02-04': {'edit_count': 1,
#   'sentiment': -0.9996967315673828,
#   'neg_sentiment': 1.0},
#  '2011-02-05': {'edit_count': 2,
#   'sentiment': -0.9946050941944122,
#   'neg_sentiment': 1.0},
#  '2011-02-06': {'edit_count': 6,
#   'sentiment': -0.6925411721070608,
#   'neg_sentiment': 0.8333333333333334},
#  '2011-02-10': {'edit_count': 8,
#   'sentiment': -0.3353150263428688,
#   'neg_sentiment': 0.625},
#  '2011-02-11': {'edit_count': 8,
#   'sentiment': 0.39717812091112137,
#   'neg_sentiment': 0.25},
#  '2011-02-12': {'edit_count': 5,
#   'sentiment': -0.578157639503479,
#   'neg_sentiment': 0.8},
#  '2011-02-13': {'edit_count': 2,
#   'sentiment': -0.7603673040866852,
#   'neg_sentiment': 1.0},
#  '2011-02-14': {'edit_count': 2,
#   'sentiment': -0.9968923032283783,
#   'neg_sentiment': 1.0},
#  '2011-02-15': {'edit_count': 3,
#   'sentiment': -0.41021573543548584,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-02-17': {'edit_count': 4,
#   'sentiment': -0.08251066505908966,
#   'neg_sentiment': 0.5},
#  '2011-02-18': {'edit_count': 4,
#   'sentiment': -0.8350160419940948,
#   'neg_sentiment': 1.0},
#  '2011-02-20': {'edit_count': 1,
#   'sentiment': -0.9961812496185303,
#   'neg_sentiment': 1.0},
#  '2011-02-23': {'edit_count': 5,
#   'sentiment': 0.09343565702438354,
#   'neg_sentiment': 0.4},
#  '2011-02-24': {'edit_count': 1,
#   'sentiment': 0.9833248853683472,
#   'neg_sentiment': 0.0},
#  '2011-02-25': {'edit_count': 5,
#   'sentiment': -0.571194052696228,
#   'neg_sentiment': 0.8},
#  '2011-02-26': {'edit_count': 2,
#   'sentiment': 0.8703857660293579,
#   'neg_sentiment': 0.0},
#  '2011-02-28': {'edit_count': 2,
#   'sentiment': 0.20266219973564148,
#   'neg_sentiment': 0.5},
#  '2011-03-01': {'edit_count': 1,
#   'sentiment': 0.8048130869865417,
#   'neg_sentiment': 0.0},
#  '2011-03-04': {'edit_count': 2,
#   'sentiment': 0.8691599071025848,
#   'neg_sentiment': 0.0},
#  '2011-03-07': {'edit_count': 6,
#   'sentiment': -0.037564108769098915,
#   'neg_sentiment': 0.5},
#  '2011-03-08': {'edit_count': 4,
#   'sentiment': -0.5860633552074432,
#   'neg_sentiment': 0.75},
#  '2011-03-11': {'edit_count': 3,
#   'sentiment': 0.2906869053840637,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-03-12': {'edit_count': 1,
#   'sentiment': -0.9923986792564392,
#   'neg_sentiment': 1.0},
#  '2011-03-13': {'edit_count': 1,
#   'sentiment': -0.615391731262207,
#   'neg_sentiment': 1.0},
#  '2011-03-14': {'edit_count': 2,
#   'sentiment': -0.9953401684761047,
#   'neg_sentiment': 1.0},
#  '2011-03-15': {'edit_count': 1,
#   'sentiment': -0.9711604118347168,
#   'neg_sentiment': 1.0},
#  '2011-03-17': {'edit_count': 1,
#   'sentiment': -0.9251039624214172,
#   'neg_sentiment': 1.0},
#  '2011-03-18': {'edit_count': 2,
#   'sentiment': -0.05015963315963745,
#   'neg_sentiment': 0.5},
#  '2011-03-19': {'edit_count': 1,
#   'sentiment': -0.9962666630744934,
#   'neg_sentiment': 1.0},
#  '2011-03-20': {'edit_count': 5,
#   'sentiment': -0.5925114870071411,
#   'neg_sentiment': 0.8},
#  '2011-03-21': {'edit_count': 1,
#   'sentiment': 0.8048130869865417,
#   'neg_sentiment': 0.0},
#  '2011-03-22': {'edit_count': 1,
#   'sentiment': 0.8048130869865417,
#   'neg_sentiment': 0.0},
#  '2011-03-23': {'edit_count': 4,
#   'sentiment': -0.4907078742980957,
#   'neg_sentiment': 0.75},
#  '2011-03-24': {'edit_count': 1,
#   'sentiment': -0.9965630173683167,
#   'neg_sentiment': 1.0},
#  '2011-03-25': {'edit_count': 8,
#   'sentiment': -0.33145660907030106,
#   'neg_sentiment': 0.625},
#  '2011-03-26': {'edit_count': 4,
#   'sentiment': -0.12413480877876282,
#   'neg_sentiment': 0.5},
#  '2011-03-28': {'edit_count': 3,
#   'sentiment': -0.39786120255788165,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-03-29': {'edit_count': 5,
#   'sentiment': -0.21896127462387086,
#   'neg_sentiment': 0.6},
#  '2011-03-30': {'edit_count': 1,
#   'sentiment': 0.8153418302536011,
#   'neg_sentiment': 0.0},
#  '2011-04-02': {'edit_count': 4,
#   'sentiment': -0.5029853731393814,
#   'neg_sentiment': 0.75},
#  '2011-04-04': {'edit_count': 4,
#   'sentiment': 0.3119431883096695,
#   'neg_sentiment': 0.25},
#  '2011-04-05': {'edit_count': 1,
#   'sentiment': -0.9985226988792419,
#   'neg_sentiment': 1.0},
#  '2011-04-06': {'edit_count': 7,
#   'sentiment': 0.3393155676977975,
#   'neg_sentiment': 0.2857142857142857},
#  '2011-04-09': {'edit_count': 2,
#   'sentiment': 0.009099960327148438,
#   'neg_sentiment': 0.5},
#  '2011-04-11': {'edit_count': 5,
#   'sentiment': -0.25824389457702634,
#   'neg_sentiment': 0.6},
#  '2011-04-12': {'edit_count': 10,
#   'sentiment': 0.2708121359348297,
#   'neg_sentiment': 0.3},
#  '2011-04-13': {'edit_count': 5,
#   'sentiment': -0.6402590274810791,
#   'neg_sentiment': 0.8},
#  '2011-04-14': {'edit_count': 7,
#   'sentiment': -0.4999713216509138,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-04-16': {'edit_count': 13,
#   'sentiment': -0.3079333076110253,
#   'neg_sentiment': 0.6153846153846154},
#  '2011-04-17': {'edit_count': 2,
#   'sentiment': 0.9950544536113739,
#   'neg_sentiment': 0.0},
#  '2011-04-18': {'edit_count': 2,
#   'sentiment': -0.9971082508563995,
#   'neg_sentiment': 1.0},
#  '2011-04-19': {'edit_count': 8,
#   'sentiment': -0.49243099987506866,
#   'neg_sentiment': 0.75},
#  '2011-04-20': {'edit_count': 3,
#   'sentiment': -0.9985311031341553,
#   'neg_sentiment': 1.0},
#  '2011-04-21': {'edit_count': 2,
#   'sentiment': -0.12399932742118835,
#   'neg_sentiment': 0.5},
#  '2011-04-22': {'edit_count': 3,
#   'sentiment': 0.2815062801043193,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-04-24': {'edit_count': 1,
#   'sentiment': 0.6554891467094421,
#   'neg_sentiment': 0.0},
#  '2011-04-25': {'edit_count': 1,
#   'sentiment': -0.995245635509491,
#   'neg_sentiment': 1.0},
#  '2011-04-26': {'edit_count': 3,
#   'sentiment': 0.2868932286898295,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-04-27': {'edit_count': 8,
#   'sentiment': -0.30213119089603424,
#   'neg_sentiment': 0.625},
#  '2011-04-28': {'edit_count': 3,
#   'sentiment': -0.35738537708918255,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-04-29': {'edit_count': 5,
#   'sentiment': 0.10089011192321777,
#   'neg_sentiment': 0.4},
#  '2011-04-30': {'edit_count': 1,
#   'sentiment': 0.990734338760376,
#   'neg_sentiment': 0.0},
#  '2011-05-02': {'edit_count': 5,
#   'sentiment': -0.22274807691574097,
#   'neg_sentiment': 0.6},
#  '2011-05-03': {'edit_count': 2,
#   'sentiment': 0.6941742300987244,
#   'neg_sentiment': 0.0},
#  '2011-05-04': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2011-05-05': {'edit_count': 12,
#   'sentiment': -0.046454171339670815,
#   'neg_sentiment': 0.5},
#  '2011-05-06': {'edit_count': 5,
#   'sentiment': -0.5827875375747681,
#   'neg_sentiment': 0.8},
#  '2011-05-08': {'edit_count': 2,
#   'sentiment': -0.9612821340560913,
#   'neg_sentiment': 1.0},
#  '2011-05-09': {'edit_count': 2,
#   'sentiment': 0.839071124792099,
#   'neg_sentiment': 0.0},
#  '2011-05-10': {'edit_count': 1,
#   'sentiment': 0.8748230338096619,
#   'neg_sentiment': 0.0},
#  '2011-05-11': {'edit_count': 1,
#   'sentiment': 0.8748230338096619,
#   'neg_sentiment': 0.0},
#  '2011-05-12': {'edit_count': 5,
#   'sentiment': -0.2720387697219849,
#   'neg_sentiment': 0.6},
#  '2011-05-14': {'edit_count': 2,
#   'sentiment': -0.15279096364974976,
#   'neg_sentiment': 0.5},
#  '2011-05-15': {'edit_count': 4,
#   'sentiment': 0.33516135811805725,
#   'neg_sentiment': 0.25},
#  '2011-05-16': {'edit_count': 7,
#   'sentiment': 0.10323971509933472,
#   'neg_sentiment': 0.42857142857142855},
#  '2011-05-17': {'edit_count': 11,
#   'sentiment': -0.1655387282371521,
#   'neg_sentiment': 0.5454545454545454},
#  '2011-05-18': {'edit_count': 10,
#   'sentiment': -0.1891336500644684,
#   'neg_sentiment': 0.6},
#  '2011-05-19': {'edit_count': 24,
#   'sentiment': -0.6198488449056944,
#   'neg_sentiment': 0.7916666666666666},
#  '2011-05-20': {'edit_count': 7,
#   'sentiment': -0.49902319056647165,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-05-21': {'edit_count': 5,
#   'sentiment': -0.594145655632019,
#   'neg_sentiment': 0.8},
#  '2011-05-22': {'edit_count': 19,
#   'sentiment': -0.5031610695939315,
#   'neg_sentiment': 0.7368421052631579},
#  '2011-05-23': {'edit_count': 9,
#   'sentiment': -0.7745044893688626,
#   'neg_sentiment': 0.8888888888888888},
#  '2011-05-24': {'edit_count': 13,
#   'sentiment': -0.539688229560852,
#   'neg_sentiment': 0.7692307692307693},
#  '2011-05-25': {'edit_count': 8,
#   'sentiment': -0.08465485274791718,
#   'neg_sentiment': 0.5},
#  '2011-05-26': {'edit_count': 27,
#   'sentiment': -0.39996761083602905,
#   'neg_sentiment': 0.7037037037037037},
#  '2011-05-27': {'edit_count': 8,
#   'sentiment': -0.02957906574010849,
#   'neg_sentiment': 0.5},
#  '2011-05-28': {'edit_count': 7,
#   'sentiment': -0.5890519022941589,
#   'neg_sentiment': 0.8571428571428571},
#  '2011-05-29': {'edit_count': 3,
#   'sentiment': -0.21549437443415323,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-05-30': {'edit_count': 5,
#   'sentiment': -0.2813813924789429,
#   'neg_sentiment': 0.6},
#  '2011-05-31': {'edit_count': 8,
#   'sentiment': -0.06665810942649841,
#   'neg_sentiment': 0.5},
#  '2011-06-01': {'edit_count': 12,
#   'sentiment': 0.46358341972033185,
#   'neg_sentiment': 0.25},
#  '2011-06-02': {'edit_count': 16,
#   'sentiment': -0.2581380642950535,
#   'neg_sentiment': 0.625},
#  '2011-06-03': {'edit_count': 41,
#   'sentiment': -0.35563239673288854,
#   'neg_sentiment': 0.6585365853658537},
#  '2011-06-04': {'edit_count': 2,
#   'sentiment': 0.0008402764797210693,
#   'neg_sentiment': 0.5},
#  '2011-06-05': {'edit_count': 9,
#   'sentiment': 0.40907298856311375,
#   'neg_sentiment': 0.2222222222222222},
#  '2011-06-06': {'edit_count': 12,
#   'sentiment': -0.8159239590167999,
#   'neg_sentiment': 0.9166666666666666},
#  '2011-06-07': {'edit_count': 5,
#   'sentiment': 0.1916877269744873,
#   'neg_sentiment': 0.4},
#  '2011-06-08': {'edit_count': 5,
#   'sentiment': 0.1975642681121826,
#   'neg_sentiment': 0.4},
#  '2011-06-09': {'edit_count': 13,
#   'sentiment': 0.3229101025141202,
#   'neg_sentiment': 0.3076923076923077},
#  '2011-06-10': {'edit_count': 7,
#   'sentiment': 0.5857181549072266,
#   'neg_sentiment': 0.14285714285714285},
#  '2011-06-11': {'edit_count': 27,
#   'sentiment': -0.6540296850381074,
#   'neg_sentiment': 0.8148148148148148},
#  '2011-06-12': {'edit_count': 49,
#   'sentiment': -0.5573634967512014,
#   'neg_sentiment': 0.7755102040816326},
#  '2011-06-13': {'edit_count': 45,
#   'sentiment': -0.2917056639989217,
#   'neg_sentiment': 0.6444444444444445},
#  '2011-06-14': {'edit_count': 26,
#   'sentiment': -0.828883171081543,
#   'neg_sentiment': 0.9230769230769231},
#  '2011-06-15': {'edit_count': 28,
#   'sentiment': -0.36274987884930204,
#   'neg_sentiment': 0.6785714285714286},
#  '2011-06-16': {'edit_count': 31,
#   'sentiment': -0.4683318541895959,
#   'neg_sentiment': 0.7419354838709677},
#  '2011-06-17': {'edit_count': 50,
#   'sentiment': -0.4822885179519653,
#   'neg_sentiment': 0.74},
#  '2011-06-18': {'edit_count': 78,
#   'sentiment': -0.33036819176796156,
#   'neg_sentiment': 0.6538461538461539},
#  '2011-06-19': {'edit_count': 24,
#   'sentiment': -0.4603525623679161,
#   'neg_sentiment': 0.7083333333333334},
#  '2011-06-20': {'edit_count': 44,
#   'sentiment': -0.06140101497823542,
#   'neg_sentiment': 0.5227272727272727},
#  '2011-06-21': {'edit_count': 22,
#   'sentiment': -0.6531901251186024,
#   'neg_sentiment': 0.8181818181818182},
#  '2011-06-22': {'edit_count': 16,
#   'sentiment': -0.6408512070775032,
#   'neg_sentiment': 0.8125},
#  '2011-06-23': {'edit_count': 14,
#   'sentiment': -0.4816250332764217,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-06-24': {'edit_count': 13,
#   'sentiment': -0.46988536761357236,
#   'neg_sentiment': 0.7692307692307693},
#  '2011-06-25': {'edit_count': 8,
#   'sentiment': -0.11764921993017197,
#   'neg_sentiment': 0.5},
#  '2011-06-26': {'edit_count': 8,
#   'sentiment': -0.883307009935379,
#   'neg_sentiment': 1.0},
#  '2011-06-27': {'edit_count': 17,
#   'sentiment': -0.20300082950031056,
#   'neg_sentiment': 0.5882352941176471},
#  '2011-06-28': {'edit_count': 2,
#   'sentiment': -0.9148055911064148,
#   'neg_sentiment': 1.0},
#  '2011-06-29': {'edit_count': 5,
#   'sentiment': -0.5984020113945008,
#   'neg_sentiment': 0.8},
#  '2011-06-30': {'edit_count': 7,
#   'sentiment': -0.45002167565482004,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-07-01': {'edit_count': 8,
#   'sentiment': -0.26348066329956055,
#   'neg_sentiment': 0.625},
#  '2011-07-02': {'edit_count': 18,
#   'sentiment': -0.2170246872637007,
#   'neg_sentiment': 0.6111111111111112},
#  '2011-07-03': {'edit_count': 7,
#   'sentiment': -0.7082808358328683,
#   'neg_sentiment': 0.8571428571428571},
#  '2011-07-04': {'edit_count': 21,
#   'sentiment': -0.24274869476045882,
#   'neg_sentiment': 0.6190476190476191},
#  '2011-07-05': {'edit_count': 4,
#   'sentiment': -0.9937280863523483,
#   'neg_sentiment': 1.0},
#  '2011-07-06': {'edit_count': 4,
#   'sentiment': -0.9985574036836624,
#   'neg_sentiment': 1.0},
#  '2011-07-07': {'edit_count': 7,
#   'sentiment': -0.4655543736049107,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-07-08': {'edit_count': 5,
#   'sentiment': 0.20583456754684448,
#   'neg_sentiment': 0.4},
#  '2011-07-09': {'edit_count': 10,
#   'sentiment': -0.5961889386177063,
#   'neg_sentiment': 0.8},
#  '2011-07-10': {'edit_count': 23,
#   'sentiment': -0.6417726718861124,
#   'neg_sentiment': 0.8260869565217391},
#  '2011-07-11': {'edit_count': 3,
#   'sentiment': -0.4165908694267273,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-07-12': {'edit_count': 14,
#   'sentiment': -0.9931866526603699,
#   'neg_sentiment': 1.0},
#  '2011-07-13': {'edit_count': 4,
#   'sentiment': 0.40493637323379517,
#   'neg_sentiment': 0.25},
#  '2011-07-14': {'edit_count': 6,
#   'sentiment': -0.10227769613265991,
#   'neg_sentiment': 0.5},
#  '2011-07-15': {'edit_count': 7,
#   'sentiment': -0.9348973546709333,
#   'neg_sentiment': 1.0},
#  '2011-07-16': {'edit_count': 1,
#   'sentiment': -0.9978852868080139,
#   'neg_sentiment': 1.0},
#  '2011-07-17': {'edit_count': 1,
#   'sentiment': -0.9991002082824707,
#   'neg_sentiment': 1.0},
#  '2011-07-18': {'edit_count': 6,
#   'sentiment': 0.24837554494539896,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-07-19': {'edit_count': 9,
#   'sentiment': -0.14822863870196873,
#   'neg_sentiment': 0.5555555555555556},
#  '2011-07-21': {'edit_count': 2,
#   'sentiment': -0.9855504631996155,
#   'neg_sentiment': 1.0},
#  '2011-07-22': {'edit_count': 6,
#   'sentiment': 0.5408847630023956,
#   'neg_sentiment': 0.16666666666666666},
#  '2011-07-23': {'edit_count': 2,
#   'sentiment': -0.002204716205596924,
#   'neg_sentiment': 0.5},
#  '2011-07-24': {'edit_count': 4,
#   'sentiment': 0.46254390478134155,
#   'neg_sentiment': 0.25},
#  '2011-07-25': {'edit_count': 4,
#   'sentiment': -0.5617953389883041,
#   'neg_sentiment': 0.75},
#  '2011-07-28': {'edit_count': 4,
#   'sentiment': 0.6786470711231232,
#   'neg_sentiment': 0.0},
#  '2011-07-29': {'edit_count': 3,
#   'sentiment': -0.33532679080963135,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-07-30': {'edit_count': 2,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2011-07-31': {'edit_count': 1,
#   'sentiment': -0.9718876481056213,
#   'neg_sentiment': 1.0},
#  '2011-08-02': {'edit_count': 6,
#   'sentiment': -0.39602747559547424,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-08-03': {'edit_count': 2,
#   'sentiment': 0.0011098980903625488,
#   'neg_sentiment': 0.5},
#  '2011-08-04': {'edit_count': 2,
#   'sentiment': -0.03633296489715576,
#   'neg_sentiment': 0.5},
#  '2011-08-05': {'edit_count': 4,
#   'sentiment': 0.31124934554100037,
#   'neg_sentiment': 0.25},
#  '2011-08-07': {'edit_count': 4,
#   'sentiment': -0.5111590325832367,
#   'neg_sentiment': 0.75},
#  '2011-08-08': {'edit_count': 4,
#   'sentiment': -0.5418855249881744,
#   'neg_sentiment': 0.75},
#  '2011-08-09': {'edit_count': 3,
#   'sentiment': -0.40914005041122437,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-08-10': {'edit_count': 5,
#   'sentiment': 0.17298147678375245,
#   'neg_sentiment': 0.4},
#  '2011-08-11': {'edit_count': 12,
#   'sentiment': -0.5211662699778875,
#   'neg_sentiment': 0.75},
#  '2011-08-12': {'edit_count': 4,
#   'sentiment': -0.006856486201286316,
#   'neg_sentiment': 0.5},
#  '2011-08-15': {'edit_count': 1,
#   'sentiment': -0.9994683861732483,
#   'neg_sentiment': 1.0},
#  '2011-08-16': {'edit_count': 1,
#   'sentiment': -0.9736192226409912,
#   'neg_sentiment': 1.0},
#  '2011-08-17': {'edit_count': 8,
#   'sentiment': 0.1931358277797699,
#   'neg_sentiment': 0.375},
#  '2011-08-19': {'edit_count': 3,
#   'sentiment': -0.9930854042371114,
#   'neg_sentiment': 1.0},
#  '2011-08-20': {'edit_count': 9,
#   'sentiment': -0.14824430810080635,
#   'neg_sentiment': 0.5555555555555556},
#  '2011-08-22': {'edit_count': 7,
#   'sentiment': -0.3977370432444981,
#   'neg_sentiment': 0.7142857142857143},
#  '2011-08-23': {'edit_count': 7,
#   'sentiment': -0.6737938182694572,
#   'neg_sentiment': 0.8571428571428571},
#  '2011-08-24': {'edit_count': 4,
#   'sentiment': -0.9043550789356232,
#   'neg_sentiment': 1.0},
#  '2011-08-25': {'edit_count': 1,
#   'sentiment': -0.9671372175216675,
#   'neg_sentiment': 1.0},
#  '2011-08-26': {'edit_count': 2,
#   'sentiment': -0.9959077835083008,
#   'neg_sentiment': 1.0},
#  '2011-08-27': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2011-08-31': {'edit_count': 1,
#   'sentiment': 0.8748230338096619,
#   'neg_sentiment': 0.0},
#  '2011-09-01': {'edit_count': 6,
#   'sentiment': -0.039308408896128334,
#   'neg_sentiment': 0.5},
#  '2011-09-02': {'edit_count': 2,
#   'sentiment': -0.9967594742774963,
#   'neg_sentiment': 1.0},
#  '2011-09-03': {'edit_count': 3,
#   'sentiment': -0.40880874792734784,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-09-04': {'edit_count': 1,
#   'sentiment': 0.9889422655105591,
#   'neg_sentiment': 0.0},
#  '2011-09-05': {'edit_count': 1,
#   'sentiment': -0.9876619577407837,
#   'neg_sentiment': 1.0},
#  '2011-09-06': {'edit_count': 1,
#   'sentiment': -0.9993465542793274,
#   'neg_sentiment': 1.0},
#  '2011-09-07': {'edit_count': 6,
#   'sentiment': 0.30167558789253235,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-09-08': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2011-09-09': {'edit_count': 3,
#   'sentiment': -0.9937077363332113,
#   'neg_sentiment': 1.0},
#  '2011-09-13': {'edit_count': 9,
#   'sentiment': -0.3645388086636861,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-09-14': {'edit_count': 4,
#   'sentiment': 7.21961259841919e-05,
#   'neg_sentiment': 0.5},
#  '2011-09-15': {'edit_count': 4,
#   'sentiment': -0.024755164980888367,
#   'neg_sentiment': 0.5},
#  '2011-09-16': {'edit_count': 8,
#   'sentiment': -0.5184010714292526,
#   'neg_sentiment': 0.75},
#  '2011-09-17': {'edit_count': 7,
#   'sentiment': -0.9975740483828953,
#   'neg_sentiment': 1.0},
#  '2011-09-18': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2011-09-19': {'edit_count': 5,
#   'sentiment': 0.1861890196800232,
#   'neg_sentiment': 0.4},
#  '2011-09-20': {'edit_count': 2,
#   'sentiment': -0.1611669957637787,
#   'neg_sentiment': 0.5},
#  '2011-09-21': {'edit_count': 6,
#   'sentiment': -0.055963218212127686,
#   'neg_sentiment': 0.5},
#  '2011-09-22': {'edit_count': 3,
#   'sentiment': -0.9824310739835104,
#   'neg_sentiment': 1.0},
#  '2011-09-25': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2011-09-26': {'edit_count': 2,
#   'sentiment': -0.01326170563697815,
#   'neg_sentiment': 0.5},
#  '2011-09-27': {'edit_count': 4,
#   'sentiment': 0.011409685015678406,
#   'neg_sentiment': 0.5},
#  '2011-09-29': {'edit_count': 4,
#   'sentiment': -0.925256222486496,
#   'neg_sentiment': 1.0},
#  '2011-09-30': {'edit_count': 2,
#   'sentiment': -0.048455625772476196,
#   'neg_sentiment': 0.5},
#  '2011-10-01': {'edit_count': 2,
#   'sentiment': -0.17213839292526245,
#   'neg_sentiment': 0.5},
#  '2011-10-02': {'edit_count': 19,
#   'sentiment': -0.2764991929656581,
#   'neg_sentiment': 0.631578947368421},
#  '2011-10-04': {'edit_count': 1,
#   'sentiment': 0.9511268734931946,
#   'neg_sentiment': 0.0},
#  '2011-10-05': {'edit_count': 4,
#   'sentiment': -0.5468896478414536,
#   'neg_sentiment': 0.75},
#  '2011-10-06': {'edit_count': 2,
#   'sentiment': -0.7648903131484985,
#   'neg_sentiment': 1.0},
#  '2011-10-07': {'edit_count': 5,
#   'sentiment': 0.09731581211090087,
#   'neg_sentiment': 0.4},
#  '2011-10-08': {'edit_count': 4,
#   'sentiment': -0.43469394743442535,
#   'neg_sentiment': 0.75},
#  '2011-10-09': {'edit_count': 9,
#   'sentiment': 0.44370532698101467,
#   'neg_sentiment': 0.2222222222222222},
#  '2011-10-10': {'edit_count': 6,
#   'sentiment': 0.3610909581184387,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-10-11': {'edit_count': 3,
#   'sentiment': -0.39522047837575275,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-13': {'edit_count': 2,
#   'sentiment': -0.034446120262145996,
#   'neg_sentiment': 0.5},
#  '2011-10-15': {'edit_count': 3,
#   'sentiment': -0.34902920325597125,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-16': {'edit_count': 2,
#   'sentiment': -0.01834028959274292,
#   'neg_sentiment': 0.5},
#  '2011-10-17': {'edit_count': 2,
#   'sentiment': -0.12550818920135498,
#   'neg_sentiment': 0.5},
#  '2011-10-18': {'edit_count': 7,
#   'sentiment': 0.02461411271776472,
#   'neg_sentiment': 0.42857142857142855},
#  '2011-10-19': {'edit_count': 2,
#   'sentiment': -0.12554162740707397,
#   'neg_sentiment': 0.5},
#  '2011-10-20': {'edit_count': 3,
#   'sentiment': 0.2530329426129659,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-10-23': {'edit_count': 9,
#   'sentiment': -0.5333169632487826,
#   'neg_sentiment': 0.7777777777777778},
#  '2011-10-24': {'edit_count': 4,
#   'sentiment': -0.09807714819908142,
#   'neg_sentiment': 0.5},
#  '2011-10-25': {'edit_count': 3,
#   'sentiment': -0.3396065831184387,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-27': {'edit_count': 3,
#   'sentiment': 0.22940927743911743,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-10-28': {'edit_count': 3,
#   'sentiment': -0.27441952625910443,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-30': {'edit_count': 3,
#   'sentiment': -0.35788331429163617,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-10-31': {'edit_count': 1,
#   'sentiment': -0.9982296824455261,
#   'neg_sentiment': 1.0},
#  '2011-11-01': {'edit_count': 4,
#   'sentiment': -0.5172291249036789,
#   'neg_sentiment': 0.75},
#  '2011-11-03': {'edit_count': 3,
#   'sentiment': 0.23611690600713095,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-11-04': {'edit_count': 1,
#   'sentiment': -0.9993987083435059,
#   'neg_sentiment': 1.0},
#  '2011-11-05': {'edit_count': 1,
#   'sentiment': -0.9985162615776062,
#   'neg_sentiment': 1.0},
#  '2011-11-06': {'edit_count': 1,
#   'sentiment': -0.8195270299911499,
#   'neg_sentiment': 1.0},
#  '2011-11-12': {'edit_count': 3,
#   'sentiment': -0.4013414184252421,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-11-13': {'edit_count': 16,
#   'sentiment': -0.605278879404068,
#   'neg_sentiment': 0.8125},
#  '2011-11-14': {'edit_count': 12,
#   'sentiment': -0.01676637927691142,
#   'neg_sentiment': 0.5},
#  '2011-11-15': {'edit_count': 2,
#   'sentiment': -0.9895029366016388,
#   'neg_sentiment': 1.0},
#  '2011-11-18': {'edit_count': 1,
#   'sentiment': -0.9997937083244324,
#   'neg_sentiment': 1.0},
#  '2011-11-20': {'edit_count': 2,
#   'sentiment': -0.11405467987060547,
#   'neg_sentiment': 0.5},
#  '2011-11-21': {'edit_count': 1,
#   'sentiment': 0.9894212484359741,
#   'neg_sentiment': 0.0},
#  '2011-11-22': {'edit_count': 3,
#   'sentiment': -0.41400347153345746,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-11-23': {'edit_count': 1,
#   'sentiment': -0.9409188032150269,
#   'neg_sentiment': 1.0},
#  '2011-11-25': {'edit_count': 3,
#   'sentiment': -0.9348674813906351,
#   'neg_sentiment': 1.0},
#  '2011-11-26': {'edit_count': 7,
#   'sentiment': 0.6696622882570539,
#   'neg_sentiment': 0.0},
#  '2011-11-27': {'edit_count': 3,
#   'sentiment': 0.1724502444267273,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-11-28': {'edit_count': 2,
#   'sentiment': -0.8722020089626312,
#   'neg_sentiment': 1.0},
#  '2011-11-29': {'edit_count': 2,
#   'sentiment': -0.029572397470474243,
#   'neg_sentiment': 0.5},
#  '2011-11-30': {'edit_count': 2,
#   'sentiment': 0.9511268734931946,
#   'neg_sentiment': 0.0},
#  '2011-12-01': {'edit_count': 4,
#   'sentiment': -0.5097887814044952,
#   'neg_sentiment': 0.75},
#  '2011-12-02': {'edit_count': 1,
#   'sentiment': -0.9950590133666992,
#   'neg_sentiment': 1.0},
#  '2011-12-04': {'edit_count': 1,
#   'sentiment': -0.9997431635856628,
#   'neg_sentiment': 1.0},
#  '2011-12-05': {'edit_count': 4,
#   'sentiment': -0.5105185657739639,
#   'neg_sentiment': 0.75},
#  '2011-12-06': {'edit_count': 2,
#   'sentiment': 0.808074951171875,
#   'neg_sentiment': 0.0},
#  '2011-12-07': {'edit_count': 2,
#   'sentiment': -0.0282612144947052,
#   'neg_sentiment': 0.5},
#  '2011-12-09': {'edit_count': 2,
#   'sentiment': -0.15644580125808716,
#   'neg_sentiment': 0.5},
#  '2011-12-10': {'edit_count': 2,
#   'sentiment': -0.8316263854503632,
#   'neg_sentiment': 1.0},
#  '2011-12-12': {'edit_count': 1,
#   'sentiment': -0.8184987902641296,
#   'neg_sentiment': 1.0},
#  '2011-12-13': {'edit_count': 1,
#   'sentiment': -0.7921800017356873,
#   'neg_sentiment': 1.0},
#  '2011-12-15': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2011-12-17': {'edit_count': 2,
#   'sentiment': -0.12560641765594482,
#   'neg_sentiment': 0.5},
#  '2011-12-18': {'edit_count': 3,
#   'sentiment': -0.7694329023361206,
#   'neg_sentiment': 1.0},
#  '2011-12-20': {'edit_count': 3,
#   'sentiment': -0.3493913809458415,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-12-21': {'edit_count': 5,
#   'sentiment': -0.5931652426719666,
#   'neg_sentiment': 0.8},
#  '2011-12-22': {'edit_count': 2,
#   'sentiment': 0.09328937530517578,
#   'neg_sentiment': 0.5},
#  '2011-12-23': {'edit_count': 1,
#   'sentiment': -0.9966469407081604,
#   'neg_sentiment': 1.0},
#  '2011-12-24': {'edit_count': 1,
#   'sentiment': 0.9518779516220093,
#   'neg_sentiment': 0.0},
#  '2011-12-25': {'edit_count': 1,
#   'sentiment': -0.9957411289215088,
#   'neg_sentiment': 1.0},
#  '2011-12-26': {'edit_count': 3,
#   'sentiment': -0.32774649063746136,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-12-28': {'edit_count': 1,
#   'sentiment': -0.9964214563369751,
#   'neg_sentiment': 1.0},
#  '2011-12-29': {'edit_count': 1,
#   'sentiment': -0.9993988275527954,
#   'neg_sentiment': 1.0},
#  '2011-12-31': {'edit_count': 2,
#   'sentiment': 0.0030662715435028076,
#   'neg_sentiment': 0.5},
#  '2012-01-01': {'edit_count': 1,
#   'sentiment': -0.9986787438392639,
#   'neg_sentiment': 1.0},
#  '2012-01-03': {'edit_count': 2,
#   'sentiment': -0.8125854730606079,
#   'neg_sentiment': 1.0},
#  '2012-01-04': {'edit_count': 2,
#   'sentiment': 0.7446615993976593,
#   'neg_sentiment': 0.0},
#  '2012-01-05': {'edit_count': 3,
#   'sentiment': 0.127256711324056,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-01-08': {'edit_count': 2,
#   'sentiment': -0.11616179347038269,
#   'neg_sentiment': 0.5},
#  '2012-01-09': {'edit_count': 5,
#   'sentiment': -0.5980123519897461,
#   'neg_sentiment': 0.8},
#  '2012-01-10': {'edit_count': 10,
#   'sentiment': -0.5917281687259675,
#   'neg_sentiment': 0.8},
#  '2012-01-12': {'edit_count': 2,
#   'sentiment': -0.13156357407569885,
#   'neg_sentiment': 0.5},
#  '2012-01-14': {'edit_count': 2,
#   'sentiment': -0.11901271343231201,
#   'neg_sentiment': 0.5},
#  '2012-01-16': {'edit_count': 7,
#   'sentiment': -0.13442081212997437,
#   'neg_sentiment': 0.5714285714285714},
#  '2012-01-17': {'edit_count': 8,
#   'sentiment': -0.5066685974597931,
#   'neg_sentiment': 0.75},
#  '2012-01-19': {'edit_count': 3,
#   'sentiment': 0.23288178443908691,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-01-21': {'edit_count': 2,
#   'sentiment': 0.0015774071216583252,
#   'neg_sentiment': 0.5},
#  '2012-01-22': {'edit_count': 1,
#   'sentiment': -0.985650360584259,
#   'neg_sentiment': 1.0},
#  '2012-01-24': {'edit_count': 6,
#   'sentiment': -0.9810291826725006,
#   'neg_sentiment': 1.0},
#  '2012-01-26': {'edit_count': 2,
#   'sentiment': 0.004887640476226807,
#   'neg_sentiment': 0.5},
#  '2012-01-28': {'edit_count': 2,
#   'sentiment': -0.023553162813186646,
#   'neg_sentiment': 0.5},
#  '2012-02-01': {'edit_count': 3,
#   'sentiment': -0.9548492630322775,
#   'neg_sentiment': 1.0},
#  '2012-02-03': {'edit_count': 2,
#   'sentiment': 0.7683715224266052,
#   'neg_sentiment': 0.0},
#  '2012-02-05': {'edit_count': 1,
#   'sentiment': -0.9974821209907532,
#   'neg_sentiment': 1.0},
#  '2012-02-07': {'edit_count': 2,
#   'sentiment': 0.0005960166454315186,
#   'neg_sentiment': 0.5},
#  '2012-02-08': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2012-02-09': {'edit_count': 2,
#   'sentiment': -0.9905492663383484,
#   'neg_sentiment': 1.0},
#  '2012-02-11': {'edit_count': 2,
#   'sentiment': -0.9969708621501923,
#   'neg_sentiment': 1.0},
#  '2012-02-12': {'edit_count': 2,
#   'sentiment': 1.3113021850585938e-05,
#   'neg_sentiment': 0.5},
#  '2012-02-13': {'edit_count': 4,
#   'sentiment': -0.005407050251960754,
#   'neg_sentiment': 0.5},
#  '2012-02-14': {'edit_count': 2,
#   'sentiment': -0.12408924102783203,
#   'neg_sentiment': 0.5},
#  '2012-02-16': {'edit_count': 2,
#   'sentiment': -0.1481851041316986,
#   'neg_sentiment': 0.5},
#  '2012-02-17': {'edit_count': 1,
#   'sentiment': -0.9860799908638,
#   'neg_sentiment': 1.0},
#  '2012-02-18': {'edit_count': 4,
#   'sentiment': -0.8176406472921371,
#   'neg_sentiment': 1.0},
#  '2012-02-19': {'edit_count': 6,
#   'sentiment': -0.3430979251861572,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-02-20': {'edit_count': 3,
#   'sentiment': 0.7674261331558228,
#   'neg_sentiment': 0.0},
#  '2012-02-21': {'edit_count': 3,
#   'sentiment': -0.40921276807785034,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-02-23': {'edit_count': 2,
#   'sentiment': 0.05482679605484009,
#   'neg_sentiment': 0.5},
#  '2012-02-24': {'edit_count': 1,
#   'sentiment': -0.9939278364181519,
#   'neg_sentiment': 1.0},
#  '2012-02-25': {'edit_count': 1,
#   'sentiment': -0.7921800017356873,
#   'neg_sentiment': 1.0},
#  '2012-02-28': {'edit_count': 2,
#   'sentiment': 0.8440601229667664,
#   'neg_sentiment': 0.0},
#  '2012-02-29': {'edit_count': 2,
#   'sentiment': -0.9982721209526062,
#   'neg_sentiment': 1.0},
#  '2012-03-01': {'edit_count': 1,
#   'sentiment': 0.7407282590866089,
#   'neg_sentiment': 0.0},
#  '2012-03-03': {'edit_count': 13,
#   'sentiment': -0.32594857766078067,
#   'neg_sentiment': 0.6923076923076923},
#  '2012-03-04': {'edit_count': 1,
#   'sentiment': 0.9271300435066223,
#   'neg_sentiment': 0.0},
#  '2012-03-05': {'edit_count': 3,
#   'sentiment': 0.3039203882217407,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-03-08': {'edit_count': 2,
#   'sentiment': -0.9409895241260529,
#   'neg_sentiment': 1.0},
#  '2012-03-09': {'edit_count': 4,
#   'sentiment': 0.9320850521326065,
#   'neg_sentiment': 0.0},
#  '2012-03-11': {'edit_count': 1,
#   'sentiment': 0.972609281539917,
#   'neg_sentiment': 0.0},
#  '2012-03-12': {'edit_count': 9,
#   'sentiment': -0.19166662295659384,
#   'neg_sentiment': 0.5555555555555556},
#  '2012-03-16': {'edit_count': 2,
#   'sentiment': -0.003813713788986206,
#   'neg_sentiment': 0.5},
#  '2012-03-17': {'edit_count': 1,
#   'sentiment': 0.9955694079399109,
#   'neg_sentiment': 0.0},
#  '2012-03-18': {'edit_count': 3,
#   'sentiment': 0.32707573970158893,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-03-19': {'edit_count': 3,
#   'sentiment': 0.4740097125371297,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-03-20': {'edit_count': 1,
#   'sentiment': 0.9981282353401184,
#   'neg_sentiment': 0.0},
#  '2012-03-21': {'edit_count': 1,
#   'sentiment': 0.9874131679534912,
#   'neg_sentiment': 0.0},
#  '2012-03-22': {'edit_count': 1,
#   'sentiment': -0.7921800017356873,
#   'neg_sentiment': 1.0},
#  '2012-03-23': {'edit_count': 6,
#   'sentiment': -0.3881908357143402,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-03-29': {'edit_count': 1,
#   'sentiment': 0.9511268734931946,
#   'neg_sentiment': 0.0},
#  '2012-04-01': {'edit_count': 4,
#   'sentiment': -0.5594567805528641,
#   'neg_sentiment': 0.75},
#  '2012-04-02': {'edit_count': 4,
#   'sentiment': 0.4000925123691559,
#   'neg_sentiment': 0.25},
#  '2012-04-03': {'edit_count': 3,
#   'sentiment': 0.8511461218198141,
#   'neg_sentiment': 0.0},
#  '2012-04-05': {'edit_count': 6,
#   'sentiment': -0.971592366695404,
#   'neg_sentiment': 1.0},
#  '2012-04-06': {'edit_count': 6,
#   'sentiment': -0.04684330026308695,
#   'neg_sentiment': 0.5},
#  '2012-04-07': {'edit_count': 1,
#   'sentiment': -0.999650239944458,
#   'neg_sentiment': 1.0},
#  '2012-04-08': {'edit_count': 7,
#   'sentiment': -0.367270256791796,
#   'neg_sentiment': 0.7142857142857143},
#  '2012-04-09': {'edit_count': 3,
#   'sentiment': -0.3766913612683614,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-04-10': {'edit_count': 2,
#   'sentiment': 0.7975439727306366,
#   'neg_sentiment': 0.0},
#  '2012-04-13': {'edit_count': 8,
#   'sentiment': -0.27054689079523087,
#   'neg_sentiment': 0.625},
#  '2012-04-15': {'edit_count': 1,
#   'sentiment': -0.9997593760490417,
#   'neg_sentiment': 1.0},
#  '2012-04-17': {'edit_count': 2,
#   'sentiment': -0.8937886357307434,
#   'neg_sentiment': 1.0},
#  '2012-04-18': {'edit_count': 1,
#   'sentiment': 0.9271300435066223,
#   'neg_sentiment': 0.0},
#  '2012-04-20': {'edit_count': 1,
#   'sentiment': -0.9608961343765259,
#   'neg_sentiment': 1.0},
#  '2012-04-23': {'edit_count': 4,
#   'sentiment': -0.5571864545345306,
#   'neg_sentiment': 0.75},
#  '2012-04-24': {'edit_count': 1,
#   'sentiment': -0.9994528889656067,
#   'neg_sentiment': 1.0},
#  '2012-04-30': {'edit_count': 1,
#   'sentiment': 0.6861284971237183,
#   'neg_sentiment': 0.0},
#  '2012-05-02': {'edit_count': 3,
#   'sentiment': -0.9965261220932007,
#   'neg_sentiment': 1.0},
#  '2012-05-03': {'edit_count': 1,
#   'sentiment': -0.7921800017356873,
#   'neg_sentiment': 1.0},
#  '2012-05-04': {'edit_count': 2,
#   'sentiment': -0.18315598368644714,
#   'neg_sentiment': 0.5},
#  '2012-05-06': {'edit_count': 1,
#   'sentiment': 0.6268866062164307,
#   'neg_sentiment': 0.0},
#  '2012-05-07': {'edit_count': 3,
#   'sentiment': 0.23814002672831217,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-05-12': {'edit_count': 3,
#   'sentiment': 0.27478394905726117,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-05-15': {'edit_count': 5,
#   'sentiment': -0.21650991439819336,
#   'neg_sentiment': 0.6},
#  '2012-05-16': {'edit_count': 1,
#   'sentiment': -0.9989104270935059,
#   'neg_sentiment': 1.0},
#  '2012-05-17': {'edit_count': 3,
#   'sentiment': -0.37239231665929157,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-05-18': {'edit_count': 1,
#   'sentiment': 0.990260899066925,
#   'neg_sentiment': 0.0},
#  '2012-05-21': {'edit_count': 1,
#   'sentiment': -0.9982331991195679,
#   'neg_sentiment': 1.0},
#  '2012-05-22': {'edit_count': 1,
#   'sentiment': -0.9419376254081726,
#   'neg_sentiment': 1.0},
#  '2012-05-23': {'edit_count': 1,
#   'sentiment': 0.6268866062164307,
#   'neg_sentiment': 0.0},
#  '2012-05-25': {'edit_count': 4,
#   'sentiment': 0.3615092486143112,
#   'neg_sentiment': 0.25},
#  '2012-05-26': {'edit_count': 3,
#   'sentiment': 0.7712309757868449,
#   'neg_sentiment': 0.0},
#  '2012-05-28': {'edit_count': 2,
#   'sentiment': -0.09116843342781067,
#   'neg_sentiment': 0.5},
#  '2012-05-30': {'edit_count': 2,
#   'sentiment': -0.961582601070404,
#   'neg_sentiment': 1.0},
#  '2012-06-01': {'edit_count': 3,
#   'sentiment': 0.16555323203404745,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-06-02': {'edit_count': 1,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2012-06-03': {'edit_count': 1,
#   'sentiment': -0.9889057874679565,
#   'neg_sentiment': 1.0},
#  '2012-06-04': {'edit_count': 2,
#   'sentiment': -0.9980162978172302,
#   'neg_sentiment': 1.0},
#  '2012-06-05': {'edit_count': 5,
#   'sentiment': 0.5632963895797729,
#   'neg_sentiment': 0.2},
#  '2012-06-08': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2012-06-09': {'edit_count': 3,
#   'sentiment': -0.3538384636243184,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-06-10': {'edit_count': 4,
#   'sentiment': -0.9982579350471497,
#   'neg_sentiment': 1.0},
#  '2012-06-11': {'edit_count': 1,
#   'sentiment': -0.9955434203147888,
#   'neg_sentiment': 1.0},
#  '2012-06-13': {'edit_count': 2,
#   'sentiment': -0.03418663144111633,
#   'neg_sentiment': 0.5},
#  '2012-06-14': {'edit_count': 1,
#   'sentiment': -0.9148892164230347,
#   'neg_sentiment': 1.0},
#  '2012-06-15': {'edit_count': 3,
#   'sentiment': -0.3288454016049703,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-06-21': {'edit_count': 1,
#   'sentiment': 0.7481208443641663,
#   'neg_sentiment': 0.0},
#  '2012-06-22': {'edit_count': 1,
#   'sentiment': 0.7485949397087097,
#   'neg_sentiment': 0.0},
#  '2012-06-24': {'edit_count': 1,
#   'sentiment': -0.9975455403327942,
#   'neg_sentiment': 1.0},
#  '2012-06-25': {'edit_count': 2,
#   'sentiment': -0.12583845853805542,
#   'neg_sentiment': 0.5},
#  '2012-06-26': {'edit_count': 1,
#   'sentiment': -0.9438227415084839,
#   'neg_sentiment': 1.0},
#  '2012-06-27': {'edit_count': 3,
#   'sentiment': 0.2783483664194743,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-06-28': {'edit_count': 2,
#   'sentiment': -0.11611434817314148,
#   'neg_sentiment': 0.5},
#  '2012-06-29': {'edit_count': 2,
#   'sentiment': -0.031746864318847656,
#   'neg_sentiment': 0.5},
#  '2012-06-30': {'edit_count': 6,
#   'sentiment': -0.010006139675776163,
#   'neg_sentiment': 0.5},
#  '2012-07-01': {'edit_count': 6,
#   'sentiment': -0.9052086174488068,
#   'neg_sentiment': 1.0},
#  '2012-07-02': {'edit_count': 3,
#   'sentiment': -0.9996555844942728,
#   'neg_sentiment': 1.0},
#  '2012-07-03': {'edit_count': 3,
#   'sentiment': -0.4612348675727844,
#   'neg_sentiment': 0.6666666666666666},
#  '2012-07-06': {'edit_count': 2,
#   'sentiment': -0.008378267288208008,
#   'neg_sentiment': 0.5},
#  '2012-07-07': {'edit_count': 1,
#   'sentiment': -0.99940025806427,
#   'neg_sentiment': 1.0},
#  '2012-07-08': {'edit_count': 2,
#   'sentiment': -0.12581557035446167,
#   'neg_sentiment': 0.5},
#  '2012-07-10': {'edit_count': 4,
#   'sentiment': -0.4813982993364334,
#   'neg_sentiment': 0.75},
#  '2012-07-11': {'edit_count': 1,
#   'sentiment': -0.8584824204444885,
#   'neg_sentiment': 1.0},
#  '2012-07-12': {'edit_count': 1,
#   'sentiment': -0.7035759687423706,
#   'neg_sentiment': 1.0},
#  '2012-07-13': {'edit_count': 2,
#   'sentiment': -0.9802581965923309,
#   'neg_sentiment': 1.0},
#  '2012-07-16': {'edit_count': 2,
#   'sentiment': -0.03483158349990845,
#   'neg_sentiment': 0.5},
#  '2012-07-18': {'edit_count': 3,
#   'sentiment': -0.9255265196164449,
#   'neg_sentiment': 1.0},
#  '2012-07-19': {'edit_count': 1,
#   'sentiment': 0.948284924030304,
#   'neg_sentiment': 0.0},
#  '2012-07-20': {'edit_count': 1,
#   'sentiment': -0.9743044972419739,
#   'neg_sentiment': 1.0},
#  '2012-07-21': {'edit_count': 3,
#   'sentiment': -0.9984828035036722,
#   'neg_sentiment': 1.0},
#  '2012-07-22': {'edit_count': 1,
#   'sentiment': -0.998062789440155,
#   'neg_sentiment': 1.0},
#  '2012-07-31': {'edit_count': 5,
#   'sentiment': -0.9929562330245971,
#   'neg_sentiment': 1.0},
#  '2012-08-01': {'edit_count': 2,
#   'sentiment': -0.9969570934772491,
#   'neg_sentiment': 1.0},
#  '2012-08-02': {'edit_count': 3,
#   'sentiment': 0.789160430431366,
#   'neg_sentiment': 0.0},
#  '2012-08-03': {'edit_count': 2,
#   'sentiment': -0.949650764465332,
#   'neg_sentiment': 1.0},
#  '2012-08-06': {'edit_count': 3,
#   'sentiment': 0.3299106955528259,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-08-07': {'edit_count': 6,
#   'sentiment': -0.650501569112142,
#   'neg_sentiment': 0.8333333333333334},
#  '2012-08-08': {'edit_count': 2,
#   'sentiment': -0.1227537989616394,
#   'neg_sentiment': 0.5},
#  '2012-08-10': {'edit_count': 2,
#   'sentiment': -0.12417420744895935,
#   'neg_sentiment': 0.5},
#  '2012-08-13': {'edit_count': 2,
#   'sentiment': -0.9970331490039825,
#   'neg_sentiment': 1.0},
#  '2012-08-14': {'edit_count': 1,
#   'sentiment': 0.6268866062164307,
#   'neg_sentiment': 0.0},
#  '2012-08-15': {'edit_count': 153,
#   'sentiment': 0.38882630011614633,
#   'neg_sentiment': 0.22875816993464052},
#  '2012-08-16': {'edit_count': 10,
#   'sentiment': -0.11283762454986572,
#   'neg_sentiment': 0.5},
#  '2012-08-17': {'edit_count': 5,
#   'sentiment': 0.16002923250198364,
#   'neg_sentiment': 0.4},
#  '2012-08-18': {'edit_count': 8,
#   'sentiment': -0.9846624210476875,
#   'neg_sentiment': 1.0},
#  '2012-08-19': {'edit_count': 4,
#   'sentiment': -0.5884185880422592,
# ...
#  '2014-01-12': {'edit_count': 12,
#   'sentiment': -0.3625996957222621,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-01-13': {'edit_count': 5,
#   'sentiment': -0.1935699462890625,
#   'neg_sentiment': 0.6},
#  '2014-01-14': {'edit_count': 8,
#   'sentiment': -0.5688721910119057,
#   'neg_sentiment': 0.75},
#  '2014-01-15': {'edit_count': 8,
#   'sentiment': -0.987766683101654,
#   'neg_sentiment': 1.0},
#  '2014-01-16': {'edit_count': 19,
#   'sentiment': -0.20532182329579404,
#   'neg_sentiment': 0.5789473684210527},
#  '2014-01-17': {'edit_count': 15,
#   'sentiment': -0.7313326120376586,
#   'neg_sentiment': 0.8666666666666667},
#  '2014-01-18': {'edit_count': 2,
#   'sentiment': -0.9962698519229889,
#   'neg_sentiment': 1.0},
#  '2014-01-19': {'edit_count': 5,
#   'sentiment': -0.618571650981903,
#   'neg_sentiment': 0.8},
#  '2014-01-20': {'edit_count': 17,
#   'sentiment': -0.672018990797155,
#   'neg_sentiment': 0.8235294117647058},
#  '2014-01-21': {'edit_count': 26,
#   'sentiment': -0.36277482830561125,
#   'neg_sentiment': 0.6923076923076923},
#  '2014-01-22': {'edit_count': 8,
#   'sentiment': -0.7295096442103386,
#   'neg_sentiment': 0.875},
#  '2014-01-23': {'edit_count': 9,
#   'sentiment': -0.5481151408619351,
#   'neg_sentiment': 0.7777777777777778},
#  '2014-01-24': {'edit_count': 4,
#   'sentiment': -0.9580045789480209,
#   'neg_sentiment': 1.0},
#  '2014-01-25': {'edit_count': 14,
#   'sentiment': -0.7042791758264814,
#   'neg_sentiment': 0.8571428571428571},
#  '2014-01-26': {'edit_count': 3,
#   'sentiment': 0.3239346146583557,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-01-27': {'edit_count': 19,
#   'sentiment': 0.04062978844893606,
#   'neg_sentiment': 0.47368421052631576},
#  '2014-01-28': {'edit_count': 44,
#   'sentiment': -0.4912554635242982,
#   'neg_sentiment': 0.75},
#  '2014-01-29': {'edit_count': 36,
#   'sentiment': -0.36862197518348694,
#   'neg_sentiment': 0.6944444444444444},
#  '2014-01-30': {'edit_count': 20,
#   'sentiment': -0.5056375354528427,
#   'neg_sentiment': 0.75},
#  '2014-01-31': {'edit_count': 7,
#   'sentiment': 0.11740866729191371,
#   'neg_sentiment': 0.42857142857142855},
#  '2014-02-01': {'edit_count': 3,
#   'sentiment': -0.28944265842437744,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-02': {'edit_count': 2,
#   'sentiment': -0.9798690676689148,
#   'neg_sentiment': 1.0},
#  '2014-02-03': {'edit_count': 2,
#   'sentiment': -0.029287904500961304,
#   'neg_sentiment': 0.5},
#  '2014-02-04': {'edit_count': 4,
#   'sentiment': -0.5030262023210526,
#   'neg_sentiment': 0.75},
#  '2014-02-05': {'edit_count': 6,
#   'sentiment': -0.331463744242986,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-06': {'edit_count': 14,
#   'sentiment': -0.4152359536715916,
#   'neg_sentiment': 0.7142857142857143},
#  '2014-02-07': {'edit_count': 3,
#   'sentiment': -0.3298684358596802,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-08': {'edit_count': 12,
#   'sentiment': -0.14854969580968222,
#   'neg_sentiment': 0.5833333333333334},
#  '2014-02-09': {'edit_count': 6,
#   'sentiment': -0.6533435881137848,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-02-10': {'edit_count': 5,
#   'sentiment': -0.5181591868400574,
#   'neg_sentiment': 0.8},
#  '2014-02-11': {'edit_count': 16,
#   'sentiment': -0.9769334457814693,
#   'neg_sentiment': 1.0},
#  '2014-02-12': {'edit_count': 9,
#   'sentiment': -0.9923609031571282,
#   'neg_sentiment': 1.0},
#  '2014-02-13': {'edit_count': 11,
#   'sentiment': -0.4849506345662204,
#   'neg_sentiment': 0.7272727272727273},
#  '2014-02-14': {'edit_count': 9,
#   'sentiment': -0.9364734159575568,
#   'neg_sentiment': 1.0},
#  '2014-02-15': {'edit_count': 3,
#   'sentiment': -0.9974373579025269,
#   'neg_sentiment': 1.0},
#  '2014-02-16': {'edit_count': 6,
#   'sentiment': -0.6640868584314982,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-02-17': {'edit_count': 4,
#   'sentiment': -0.49974024295806885,
#   'neg_sentiment': 0.75},
#  '2014-02-19': {'edit_count': 3,
#   'sentiment': -0.3088584939638774,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-02-21': {'edit_count': 3,
#   'sentiment': -0.9966362913449606,
#   'neg_sentiment': 1.0},
#  '2014-02-22': {'edit_count': 2,
#   'sentiment': -0.012674301862716675,
#   'neg_sentiment': 0.5},
#  '2014-02-23': {'edit_count': 1,
#   'sentiment': -0.9707513451576233,
#   'neg_sentiment': 1.0},
#  '2014-02-24': {'edit_count': 1,
#   'sentiment': -0.9905113577842712,
#   'neg_sentiment': 1.0},
#  '2014-02-25': {'edit_count': 11,
#   'sentiment': -0.4450432766567577,
#   'neg_sentiment': 0.7272727272727273},
#  '2014-02-26': {'edit_count': 8,
#   'sentiment': -0.9863353967666626,
#   'neg_sentiment': 1.0},
#  '2014-02-27': {'edit_count': 2,
#   'sentiment': -0.9991008937358856,
#   'neg_sentiment': 1.0},
#  '2014-02-28': {'edit_count': 3,
#   'sentiment': -0.33364685376485187,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-03-01': {'edit_count': 29,
#   'sentiment': -0.5178192155114536,
#   'neg_sentiment': 0.7586206896551724},
#  '2014-03-02': {'edit_count': 10,
#   'sentiment': -0.597107070684433,
#   'neg_sentiment': 0.8},
#  '2014-03-03': {'edit_count': 8,
#   'sentiment': 0.21805308759212494,
#   'neg_sentiment': 0.375},
#  '2014-03-04': {'edit_count': 14,
#   'sentiment': -0.07287230236189705,
#   'neg_sentiment': 0.5},
#  '2014-03-05': {'edit_count': 28,
#   'sentiment': -0.8754771628550121,
#   'neg_sentiment': 0.9285714285714286},
#  '2014-03-06': {'edit_count': 26,
#   'sentiment': -0.8906703064074883,
#   'neg_sentiment': 0.9615384615384616},
#  '2014-03-07': {'edit_count': 17,
#   'sentiment': -0.5486808945150936,
#   'neg_sentiment': 0.7647058823529411},
#  '2014-03-08': {'edit_count': 25,
#   'sentiment': -0.6967322826385498,
#   'neg_sentiment': 0.84},
#  '2014-03-09': {'edit_count': 12,
#   'sentiment': -0.8042899668216705,
#   'neg_sentiment': 0.9166666666666666},
#  '2014-03-10': {'edit_count': 18,
#   'sentiment': -0.8799352712101407,
#   'neg_sentiment': 0.9444444444444444},
#  '2014-03-11': {'edit_count': 29,
#   'sentiment': -0.7291558857621818,
#   'neg_sentiment': 0.8620689655172413},
#  '2014-03-12': {'edit_count': 18,
#   'sentiment': -0.774095916085773,
#   'neg_sentiment': 0.8888888888888888},
#  '2014-03-13': {'edit_count': 19,
#   'sentiment': -0.5863953766069914,
#   'neg_sentiment': 0.7894736842105263},
#  '2014-03-14': {'edit_count': 8,
#   'sentiment': -0.9605889618396759,
#   'neg_sentiment': 1.0},
#  '2014-03-15': {'edit_count': 7,
#   'sentiment': -0.7515902263777596,
#   'neg_sentiment': 0.8571428571428571},
#  '2014-03-16': {'edit_count': 1,
#   'sentiment': -0.9995993971824646,
#   'neg_sentiment': 1.0},
#  '2014-03-17': {'edit_count': 12,
#   'sentiment': -0.5197486033042272,
#   'neg_sentiment': 0.75},
#  '2014-03-18': {'edit_count': 15,
#   'sentiment': -0.5682886640230814,
#   'neg_sentiment': 0.8},
#  '2014-03-19': {'edit_count': 20,
#   'sentiment': -0.6367598503828049,
#   'neg_sentiment': 0.8},
#  '2014-03-20': {'edit_count': 25,
#   'sentiment': -0.682227053642273,
#   'neg_sentiment': 0.84},
#  '2014-03-21': {'edit_count': 19,
#   'sentiment': -0.26737739537891586,
#   'neg_sentiment': 0.631578947368421},
#  '2014-03-22': {'edit_count': 12,
#   'sentiment': 0.28276318311691284,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-03-23': {'edit_count': 24,
#   'sentiment': -0.7468099196751913,
#   'neg_sentiment': 0.875},
#  '2014-03-24': {'edit_count': 1,
#   'sentiment': -0.9668273329734802,
#   'neg_sentiment': 1.0},
#  '2014-03-25': {'edit_count': 18,
#   'sentiment': -0.15062648389074537,
#   'neg_sentiment': 0.5555555555555556},
#  '2014-03-26': {'edit_count': 11,
#   'sentiment': -0.6365211118351329,
#   'neg_sentiment': 0.8181818181818182},
#  '2014-03-27': {'edit_count': 9,
#   'sentiment': -0.2198094262017144,
#   'neg_sentiment': 0.5555555555555556},
#  '2014-03-28': {'edit_count': 43,
#   'sentiment': -0.5981732703918634,
#   'neg_sentiment': 0.7906976744186046},
#  '2014-03-29': {'edit_count': 16,
#   'sentiment': -0.7041314989328384,
#   'neg_sentiment': 0.875},
#  '2014-03-30': {'edit_count': 38,
#   'sentiment': -0.4484735397916091,
#   'neg_sentiment': 0.7105263157894737},
#  '2014-03-31': {'edit_count': 22,
#   'sentiment': -0.8101093633608385,
#   'neg_sentiment': 0.9090909090909091},
#  '2014-04-01': {'edit_count': 29,
#   'sentiment': 0.03442729547105987,
#   'neg_sentiment': 0.4482758620689655},
#  '2014-04-02': {'edit_count': 53,
#   'sentiment': -0.4888775652309634,
#   'neg_sentiment': 0.7358490566037735},
#  '2014-04-03': {'edit_count': 9,
#   'sentiment': -0.5863240891032748,
#   'neg_sentiment': 0.7777777777777778},
#  '2014-04-04': {'edit_count': 36,
#   'sentiment': -0.5125320123301612,
#   'neg_sentiment': 0.75},
#  '2014-04-05': {'edit_count': 1,
#   'sentiment': -0.9993259906768799,
#   'neg_sentiment': 1.0},
#  '2014-04-06': {'edit_count': 2,
#   'sentiment': -0.005591243505477905,
#   'neg_sentiment': 0.5},
#  '2014-04-07': {'edit_count': 13,
#   'sentiment': 0.1706608488009526,
#   'neg_sentiment': 0.38461538461538464},
#  '2014-04-08': {'edit_count': 8,
#   'sentiment': 0.4292139410972595,
#   'neg_sentiment': 0.25},
#  '2014-04-09': {'edit_count': 16,
#   'sentiment': -0.7389361932873726,
#   'neg_sentiment': 0.875},
#  '2014-04-10': {'edit_count': 6,
#   'sentiment': 0.12884417176246643,
#   'neg_sentiment': 0.3333333333333333},
#  '2014-04-11': {'edit_count': 8,
#   'sentiment': 0.12287262827157974,
#   'neg_sentiment': 0.375},
#  '2014-04-12': {'edit_count': 7,
#   'sentiment': -0.40493686710085186,
#   'neg_sentiment': 0.7142857142857143},
#  '2014-04-13': {'edit_count': 15,
#   'sentiment': -0.8522640784581502,
#   'neg_sentiment': 0.9333333333333333},
#  '2014-04-14': {'edit_count': 8,
#   'sentiment': -0.745801642537117,
#   'neg_sentiment': 0.875},
#  '2014-04-15': {'edit_count': 27,
#   'sentiment': -0.4525492279617875,
#   'neg_sentiment': 0.7037037037037037},
#  '2014-04-16': {'edit_count': 47,
#   'sentiment': -0.47192033554645296,
#   'neg_sentiment': 0.723404255319149},
#  '2014-04-17': {'edit_count': 20,
#   'sentiment': -0.6488602936267853,
#   'neg_sentiment': 0.85},
#  '2014-04-18': {'edit_count': 119,
#   'sentiment': -0.7310649993038979,
#   'neg_sentiment': 0.8739495798319328},
#  '2014-04-19': {'edit_count': 62,
#   'sentiment': -0.7448469659974498,
#   'neg_sentiment': 0.8709677419354839},
#  '2014-04-20': {'edit_count': 28,
#   'sentiment': -0.588008069566318,
#   'neg_sentiment': 0.7857142857142857},
#  '2014-04-21': {'edit_count': 36,
#   'sentiment': -0.7804075694746442,
#   'neg_sentiment': 0.8888888888888888},
#  '2014-04-22': {'edit_count': 8,
#   'sentiment': -0.5116523951292038,
#   'neg_sentiment': 0.75},
#  '2014-04-23': {'edit_count': 8,
#   'sentiment': -0.18353159725666046,
#   'neg_sentiment': 0.625},
#  '2014-04-24': {'edit_count': 23,
#   'sentiment': -0.7484409964602926,
#   'neg_sentiment': 0.8695652173913043},
#  '2014-04-25': {'edit_count': 11,
#   'sentiment': -0.1202802062034607,
#   'neg_sentiment': 0.5454545454545454},
#  '2014-04-26': {'edit_count': 11,
#   'sentiment': -0.18580947680906815,
#   'neg_sentiment': 0.5454545454545454},
#  '2014-04-27': {'edit_count': 16,
#   'sentiment': -0.6409318782389164,
#   'neg_sentiment': 0.8125},
#  '2014-04-28': {'edit_count': 7,
#   'sentiment': -0.7251836998122079,
#   'neg_sentiment': 0.8571428571428571},
#  '2014-04-29': {'edit_count': 8,
#   'sentiment': 0.3512444943189621,
#   'neg_sentiment': 0.25},
#  '2014-04-30': {'edit_count': 1,
#   'sentiment': -0.996650755405426,
#   'neg_sentiment': 1.0},
#  '2014-05-01': {'edit_count': 31,
#   'sentiment': -0.8357689188372704,
#   'neg_sentiment': 0.9354838709677419},
#  '2014-05-02': {'edit_count': 27,
#   'sentiment': -0.5058014370776989,
#   'neg_sentiment': 0.7407407407407407},
#  '2014-05-04': {'edit_count': 7,
#   'sentiment': -0.9619986670357841,
#   'neg_sentiment': 1.0},
#  '2014-05-05': {'edit_count': 15,
#   'sentiment': -0.4559679627418518,
#   'neg_sentiment': 0.7333333333333333},
#  '2014-05-06': {'edit_count': 5,
#   'sentiment': -0.20001838207244874,
#   'neg_sentiment': 0.6},
#  '2014-05-07': {'edit_count': 27,
#   'sentiment': -0.008066749131238019,
#   'neg_sentiment': 0.48148148148148145},
#  '2014-05-08': {'edit_count': 23,
#   'sentiment': -0.37475889662037726,
#   'neg_sentiment': 0.6956521739130435},
#  '2014-05-09': {'edit_count': 23,
#   'sentiment': -0.5738177429074827,
#   'neg_sentiment': 0.782608695652174},
#  '2014-05-10': {'edit_count': 27,
#   'sentiment': -0.397968331972758,
#   'neg_sentiment': 0.7037037037037037},
#  '2014-05-11': {'edit_count': 18,
#   'sentiment': -0.4832599427964952,
#   'neg_sentiment': 0.7222222222222222},
#  '2014-05-12': {'edit_count': 17,
#   'sentiment': -0.7546615565524382,
#   'neg_sentiment': 0.8823529411764706},
#  '2014-05-13': {'edit_count': 11,
#   'sentiment': -0.8121917410330339,
#   'neg_sentiment': 0.9090909090909091},
#  '2014-05-14': {'edit_count': 7,
#   'sentiment': -0.4826353703226362,
#   'neg_sentiment': 0.7142857142857143},
#  '2014-05-15': {'edit_count': 5,
#   'sentiment': -0.20148344039916993,
#   'neg_sentiment': 0.6},
#  '2014-05-16': {'edit_count': 10,
#   'sentiment': 0.3065008521080017,
#   'neg_sentiment': 0.3},
#  '2014-05-17': {'edit_count': 6,
#   'sentiment': -0.08653968572616577,
#   'neg_sentiment': 0.5},
#  '2014-05-18': {'edit_count': 5,
#   'sentiment': -0.613719356060028,
#   'neg_sentiment': 0.8},
#  '2014-05-19': {'edit_count': 12,
#   'sentiment': -0.3961380422115326,
#   'neg_sentiment': 0.6666666666666666},
#  '2014-05-20': {'edit_count': 8,
#   'sentiment': -0.24308553338050842,
#   'neg_sentiment': 0.625},
#  '2014-05-21': {'edit_count': 40,
#   'sentiment': -0.4453905329108238,
#   'neg_sentiment': 0.7},
#  '2014-05-25': {'edit_count': 4,
#   'sentiment': -0.9908394366502762,
#   'neg_sentiment': 1.0},
#  '2014-05-26': {'edit_count': 16,
#   'sentiment': -0.6232978031039238,
#   'neg_sentiment': 0.8125},
#  '2014-05-27': {'edit_count': 23,
#   'sentiment': -0.7244287573772928,
#   'neg_sentiment': 0.8695652173913043},
#  '2014-05-29': {'edit_count': 4,
#   'sentiment': -0.5470228791236877,
#   'neg_sentiment': 0.75},
#  '2014-05-30': {'edit_count': 7,
#   'sentiment': -0.9435908113207135,
#   'neg_sentiment': 1.0},
#  '2014-05-31': {'edit_count': 6,
#   'sentiment': -0.6646862129370371,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-06-01': {'edit_count': 13,
#   'sentiment': -0.5344190322435819,
#   'neg_sentiment': 0.7692307692307693},
#  '2014-06-02': {'edit_count': 8,
#   'sentiment': -0.31411660462617874,
#   'neg_sentiment': 0.625},
#  '2014-06-03': {'edit_count': 12,
#   'sentiment': -0.6949232965707779,
#   'neg_sentiment': 0.8333333333333334},
#  '2014-06-04': {'edit_count': 14,
#   'sentiment': -0.8139526801449912,
#   'neg_sentiment': 0.9285714285714286},
#  '2014-06-06': {'edit_count': 2,
#   'sentiment': -0.12103471159934998,
#   'neg_sentiment': 0.5},
#  '2014-06-07': {'edit_count': 2,
#   'sentiment': 0.9300214052200317,
#   'neg_sentiment': 0.0},
#  '2014-06-08': {'edit_count': 10,
#   'sentiment': -0.41407949328422544,
#   'neg_sentiment': 0.7},
#  '2014-06-09': {'edit_count': 4,
#   'sentiment': 0.4786435067653656,
#   'neg_sentiment': 0.25},
#  '2014-06-10': {'edit_count': 7,
#   'sentiment': -0.21231083359037126,
#   'neg_sentiment': 0.5714285714285714},
#  '2014-06-11': {'edit_count': 7,
#   'sentiment': -0.9776390620640346,
#   'neg_sentiment': 1.0},
#  '2014-06-12': {'edit_count': 4,
#   'sentiment': 0.37405629456043243,
#   'neg_sentiment': 0.25},
#  '2014-06-13': {'edit_count': 11,
#   'sentiment': -0.4965491457418962,
#   'neg_sentiment': 0.7272727272727273},
#  '2014-06-15': {'edit_count': 14,
#   'sentiment': 0.0022442894322531565,
#   'neg_sentiment': 0.5},
#  '2014-06-16': {'edit_count': 1,
#   'sentiment': 0.7185581922531128,
#   'neg_sentiment': 0.0},
#  '2014-06-17': {'edit_count': 2,
#   'sentiment': 0.017641127109527588,
#   'neg_sentiment': 0.5},
#  '2014-06-18': {'edit_count': 6,
#   'sentiment': -0.04844053586324056,
#   'neg_sentiment': 0.5},
#  '2014-06-19': {'edit_count': 1,
#   'sentiment': -0.9971330165863037,
#   'neg_sentiment': 1.0},
#  '2014-06-20': {'edit_count': 9,
#   'sentiment': -0.5853279232978821,
#   'neg_sentiment': 0.7777777777777778},
#  '2014-06-21': {'edit_count': 1,
#   'sentiment': -0.9982319474220276,
#   'neg_sentiment': 1.0},
#  '2014-06-23': {'edit_count': 1,
#   'sentiment': -0.970464289188385,
#   'neg_sentiment': 1.0},
#  '2014-06-24': {'edit_count': 3,
#   'sentiment': -0.9891805450121561,
#   'neg_sentiment': 1.0},
#  '2014-06-25': {'edit_count': 1,
#   'sentiment': -0.9990149736404419,
#   'neg_sentiment': 1.0},
#  '2014-06-26': {'edit_count': 6,
#   'sentiment': -0.27050050099690753,
#   'neg_sentiment': 0.6666666666666666},
#  ...}

# %% [markdown]
# # Converting sentiment data into dataframe

# %%
# Convert the 'edits' dictionary into a pandas DataFrame, with dates as the index
edits_df = pd.DataFrame.from_dict(edits, orient='index')

# %%
# Display the DataFrame containing the processed edit information
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-03-08           4  -0.550525           0.75
# 2009-08-05           1   0.748121           0.00
# 2009-08-06           2   0.995746           0.00
# 2009-08-14           1   0.930021           0.00
# 2009-10-13           2  -0.227499           0.50
# ...                ...        ...            ...
# 2024-07-28           2  -0.008737           0.50
# 2024-07-29           1  -0.696867           1.00
# 2024-07-31           1  -0.999386           1.00
# 2024-08-07           1   0.997663           0.00
# 2024-08-15           1  -0.999610           1.00
#
# [2712 rows x 3 columns]

# %%
# Convert the index of the DataFrame to datetime format for easier time series analysis
edits_df.index = pd.to_datetime(edits_df.index)

# %%
# Generate a date range from March 8, 2009, to today's date
dates = pd.date_range(start="2009-03-08", end=datetime.today())

# %%
# Display the generated date range
dates
# Out:
# DatetimeIndex(['2009-03-08', '2009-03-09', '2009-03-10', '2009-03-11',
#                '2009-03-12', '2009-03-13', '2009-03-14', '2009-03-15',
#                '2009-03-16', '2009-03-17',
#                ...
#                '2024-08-07', '2024-08-08', '2024-08-09', '2024-08-10',
#                '2024-08-11', '2024-08-12', '2024-08-13', '2024-08-14',
#                '2024-08-15', '2024-08-16'],
#               dtype='datetime64[ns]', length=5641, freq='D')

# %%
# Reindex the DataFrame to include all dates in the generated date range, filling missing values with 0
edits_df = edits_df.reindex(dates, fill_value=0)

# %%
# Display the DataFrame with reindexed dates and filled missing values
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-03-08           4  -0.550525           0.75
# 2009-03-09           0   0.000000           0.00
# 2009-03-10           0   0.000000           0.00
# 2009-03-11           0   0.000000           0.00
# 2009-03-12           0   0.000000           0.00
# ...                ...        ...            ...
# 2024-08-12           0   0.000000           0.00
# 2024-08-13           0   0.000000           0.00
# 2024-08-14           0   0.000000           0.00
# 2024-08-15           1  -0.999610           1.00
# 2024-08-16           0   0.000000           0.00
#
# [5641 rows x 3 columns]

# %%
# Calculate the 15-day rolling mean of the DataFrame to smooth the time series data
rolling_edits = edits_df.rolling(15).mean()

# %%
# Display the DataFrame with 15-day rolling mean applied
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-03-08         NaN        NaN            NaN
# 2009-03-09         NaN        NaN            NaN
# 2009-03-10         NaN        NaN            NaN
# 2009-03-11         NaN        NaN            NaN
# 2009-03-12         NaN        NaN            NaN
# ...                ...        ...            ...
# 2024-08-12    0.200000  -0.046573       0.133333
# 2024-08-13    0.133333  -0.000115       0.066667
# 2024-08-14    0.133333  -0.000115       0.066667
# 2024-08-15    0.133333  -0.000130       0.066667
# 2024-08-16    0.133333  -0.000130       0.066667
#
# [5641 rows x 3 columns]

# %%
# Remove rows with missing values resulting from the rolling mean calculation
rolling_edits = rolling_edits.dropna()

# %%
# Display the DataFrame with rolling mean applied and missing values removed
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-03-22    0.266667  -0.036702       0.050000
# 2009-03-23    0.000000   0.000000       0.000000
# 2009-03-24    0.000000   0.000000       0.000000
# 2009-03-25    0.000000   0.000000       0.000000
# 2009-03-26    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2024-08-12    0.200000  -0.046573       0.133333
# 2024-08-13    0.133333  -0.000115       0.066667
# 2024-08-14    0.133333  -0.000115       0.066667
# 2024-08-15    0.133333  -0.000130       0.066667
# 2024-08-16    0.133333  -0.000130       0.066667
#
# [5627 rows x 3 columns]

# %%
# Save the DataFrame with rolling mean to a CSV file
rolling_edits.to_csv("D:/VSCode Folders/Bitcoin Prediction/wikipedia edits.csv")
